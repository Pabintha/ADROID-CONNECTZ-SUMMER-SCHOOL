# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Fashion Dataset.csv.zip')
df
# Out:
#        Unnamed: 0        p_id  \
# 0               0  17048614.0
# 1               1  16524740.0
# 2               2  16331376.0
# 3               3  14709966.0
# 4               4  11056154.0
# ...           ...         ...
# 14325         985  15415116.0
# 14326         986  16470114.0
# 14327         987  16382150.0
# 14328         988  16379664.0
# 14329         989  16379656.0
#
#                                                     name   price     colour  \
# 0      Khushal K Women Black Ethnic Motifs Printed Ku...  5099.0      Black
# 1      InWeave Women Orange Solid Kurta with Palazzos...  5899.0     Orange
# 2      Anubhutee Women Navy Blue Ethnic Motifs Embroi...  4899.0  Navy Blue
# 3      Nayo Women Red Floral Printed Kurta With Trous...  3699.0        Red
# 4       AHIKA Women Black & Green Printed Straight Kurta  1350.0      Black
# ...                                                  ...     ...        ...
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0          p_id         price   ratingCount   avg_rating
# count  14330.000000  1.431200e+04  14312.000000   6581.000000  6581.000000
# mean     456.998255  1.569151e+07   2964.229248    184.479410     4.101226
# std      279.547902  3.153526e+06   2563.850645    782.501137     0.475633
# min        0.000000  7.016600e+04    169.000000      1.000000     1.000000
# 25%      215.000000  1.413619e+07   1599.000000      9.000000     3.888889
# 50%      442.500000  1.638232e+07   2200.000000     23.000000     4.180822
# 75%      687.000000  1.808456e+07   3495.000000     80.000000     4.392857
# max      989.000000  1.941576e+07  47999.000000  21274.000000     5.000000

# %%
import seaborn as sns
sns.histplot(x='avg_rating', data=df)

# %%
import matplotlib.pyplot as plt

cols = 3
rows = 3
num_cols = df.select_dtypes(exclude='object').columns
fig = plt.figure( figsize=(cols*5, rows*5))
for i, col in enumerate(num_cols):

    ax=fig.add_subplot(rows,cols,i+1)

    sns.histplot(x = df[col], ax = ax)

fig.tight_layout()
plt.show()

# %%
sns.kdeplot(x='avg_rating', data=df, hue='colour')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
sns.histplot(x='p_id', data=df, kde=True)

# %%
sns.boxplot(x=df['avg_rating'])

# %%
sns.boxplot(data=df.loc[:, ['ratingCount', 'avg_rating']])

# %%
cols = 3
rows = 3
num_cols = df.select_dtypes(exclude='object').columns
fig = plt.figure(figsize= (15,9))
for i, col in enumerate(num_cols):

    ax=fig.add_subplot( rows, cols, i+1)

    sns.boxplot(x=df[col], ax=ax)

fig.tight_layout()
plt.show()

# %%
sns.violinplot(x=df["p_id"])

# %%
sns.stripplot(x=df["avg_rating"]);

# %%
df.describe(include='object')
# Out:
#                                        name colour     brand  \
# count                                 14312  14309     14312
# unique                                13882     49      1022
# top     SCORPIOUS Women Pack of Shrug & Top  Black  Roadster
# freq                                     10   1917       346
#
#                                                       img  \
# count                                               14312
# unique                                              14223
# top     http://assets.myntassets.com/assets/images/136...
# freq                                                    2
#
#                                               description  \
# count                                               14312
# unique                                              14235
# top     White light wash 5-pocket high-rise jeans, cle...
# freq                                                    3
#
#                                              p_attributes
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,10))
ax=sns.countplot(x=df.colour)

# %%
pdf = df['colour'].value_counts()
pdf
# Out:
# Black                1917
# Blue                 1814
# Pink                 1179
# Green                1089
# Navy Blue             846
# White                 811
# Red                   714
# Grey                  572
# Maroon                527
# Yellow                498
# Beige                 487
# Mustard               325
# Off White             314
# Peach                 303
# Purple                296
# Orange                288
# Olive                 257
# Brown                 255
# Teal                  192
# Cream                 157
# Multi                 147
# Burgundy              146
# Sea Green             115
# Turquoise Blue        113
# Rust                  108
# Lavender              102
# Gold                   93
# Magenta                86
# Charcoal               84
# Coral                  81
# Fuchsia                54
# Mauve                  51
# Lime Green             50
# Rose                   44
# Grey Melange           43
# ...

# %%
plt.pie(pdf, labels=pdf.index, autopct="%.0f%%");
plt.show()

# %%
meandf = df['avg_rating'].mean()
meandf
# Out:
# 4.101225865896687

# %%
modedf = df['avg_rating'].mode()
modedf
# Out:
# 0    4.0
# dtype: float64

# %%
SD = df['avg_rating'].std()
SD
# Out:
# 0.47563329373915264

# %%
sns.distplot(df.ratingCount)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import math
import numpy as np
import pandas as pd
from matplotlib import pyplot
from scipy import stats
mu, sigma = 128, 25 # From the above example
highest_Credits = np.random.normal(mu, sigma, 1000) # Random 1000 values

count, bins, _ = pyplot.hist(highest_Credits, 100, color='lightblue') # plot 100 points
pyplot.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
    np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
    linewidth = 2, color = 'r')

# %%
sns.heatmap(df.corr())
plt.show()

# %%
df[["ratingCount","avg_rating"]].corr()
# Out:
#              ratingCount  avg_rating
# ratingCount     1.000000    0.029024
# avg_rating      0.029024    1.000000

# %%
plt.scatter(df.ratingCount,df.avg_rating)
plt.xlabel("ratingCount")
plt.ylabel("avg_rating")
plt.show()

# %%
df1 = df.dropna()
print(df1)
# Out:
#        Unnamed: 0        p_id  \
# 0               0  17048614.0
# 1               1  16524740.0
# 2               2  16331376.0
# 3               3  14709966.0
# 4               4  11056154.0
# ...           ...         ...
# 14298         958  14927330.0
# 14305         965   7275903.0
# 14313         973  16044104.0
# 14323         983  16225448.0
# 14325         985  15415116.0
#
#                                                     name   price     colour  \
# 0      Khushal K Women Black Ethnic Motifs Printed Ku...  5099.0      Black
# 1      InWeave Women Orange Solid Kurta with Palazzos...  5899.0     Orange
# 2      Anubhutee Women Navy Blue Ethnic Motifs Embroi...  4899.0  Navy Blue
# 3      Nayo Women Red Floral Printed Kurta With Trous...  3699.0        Red
# 4       AHIKA Women Black & Green Printed Straight Kurta  1350.0      Black
# ...                                                  ...     ...        ...
# ...

# %%
import scipy.stats as st
st.pearsonr(df1["avg_rating"],df1["ratingCount"])
# Out:
# (0.029024399369276095, 0.01854237267546527)

# %%
df1[["avg_rating","ratingCount"]].corr(method="pearson")
# Out:
#              avg_rating  ratingCount
# avg_rating     1.000000     0.029024
# ratingCount    0.029024     1.000000

# %%
st.spearmanr(df1["avg_rating"],df1["ratingCount"])
# Out:
# SpearmanrResult(correlation=0.02526135495067866, pvalue=0.040440238495365016)

# %%
df1[["avg_rating","ratingCount"]].corr(method="spearman")
# Out:
#              avg_rating  ratingCount
# avg_rating     1.000000     0.025261
# ratingCount    0.025261     1.000000

# %%
st.kendalltau(df1["avg_rating"],df1["ratingCount"])
# Out:
# KendalltauResult(correlation=0.015575124629649762, pvalue=0.060824191319516045)

# %%
df1[["avg_rating","ratingCount"]].corr(method="kendall")
# Out:
#              avg_rating  ratingCount
# avg_rating     1.000000     0.015575
# ratingCount    0.015575     1.000000

# %%
np.cov(df1.avg_rating,df1.ratingCount)[1,0]
# Out:
# 10.802405239412424

# %%
df1.corr()
# Out:
#              Unnamed: 0      p_id     price  ratingCount  avg_rating
# Unnamed: 0     1.000000 -0.034724 -0.026601    -0.173858   -0.061880
# p_id          -0.034724  1.000000  0.135075    -0.216366    0.028381
# price         -0.026601  0.135075  1.000000    -0.049082   -0.050766
# ratingCount   -0.173858 -0.216366 -0.049082     1.000000    0.029024
# avg_rating    -0.061880  0.028381 -0.050766     0.029024    1.000000

# %%
sns.heatmap(df1.corr())
plt.show()

# %%
plt.scatter(df1.avg_rating,df1.ratingCount)
plt.xlabel("avg_rating")
plt.ylabel("ratingCount")
plt.show()

# %%
sns.pairplot(df1, kind="scatter")
plt.show()

# %%
sns.pairplot(df1, kind="line")
plt.show()

# %%
contingency_table=pd.crosstab(index=df1["colour"],columns=df1["brand"])
contingency_table
# Out:
# brand              20Dresses  513  98 Degree North  9teenAGAIN  A.T.U.N.  \
# colour
# Assorted                   0    0                0           0         0
# Beige                      0    0                0           0         0
# Black                      2    2                2           0         1
# Blue                       2    0                0           0         0
# Brown                      0    0                0           0         0
# Burgundy                   0    0                0           0         0
# Camel Brown                0    0                0           0         0
# Charcoal                   0    0                0           0         0
# Coffee Brown               0    0                0           0         0
# Copper                     0    0                0           0         0
# Coral                      0    0                0           0         0
# Cream                      0    0                0           0         0
# ...

# %%
from scipy.stats import chi2_contingency
ChiSqResult=chi2_contingency(contingency_table)
p=ChiSqResult[1]
p
# Out:
# 4.937973113891269e-62

# %%
s = df1.groupby(['colour'])['price'].value_counts(normalize=True)
s
# Out:
# colour    price
# Assorted  1299.0     1.000000
# Beige     1699.0     0.058511
#           1999.0     0.053191
#           799.0      0.047872
#           999.0      0.047872
#                        ...
# Yellow    7751.0     0.005780
#           7900.0     0.005780
#           7990.0     0.005780
#           13500.0    0.005780
#           17000.0    0.005780
# Name: price, Length: 2494, dtype: float64

# %%
s =df1.groupby(['ratingCount'])['avg_rating'].value_counts(normalize=True)
s
# Out:
# ratingCount  avg_rating
# 1.0          4.000000      0.333333
#              5.000000      0.333333
#              1.000000      0.166667
#              2.000000      0.166667
# 2.0          5.000000      0.218391
#                              ...
# 13938.0      4.226288      1.000000
# 13947.0      3.839607      1.000000
# 16219.0      4.093286      1.000000
# 19656.0      4.488146      1.000000
# 21274.0      3.978377      1.000000
# Name: avg_rating, Length: 3237, dtype: float64

# %%
s = df1.groupby(['brand'])['price'].value_counts(normalize=True)
s
# Out:
# brand       price
# 20Dresses   1995.0    0.250
#             1495.0    0.125
#             1795.0    0.125
#             2195.0    0.125
#             2295.0    0.125
#                       ...
# trueBrowns  2999.0    1.000
# urSense     1499.0    0.500
#             2299.0    0.500
# wild U      2990.0    1.000
# zebu        1499.0    1.000
# Name: price, Length: 3001, dtype: float64

# %%
df1['price'].max()
# Out:
# 33350.0

# %%
df1['avg_rating'].max()
# Out:
# 5.0

# %%
df1.groupby(['colour']).groups.keys()
# Out:
# dict_keys(['Assorted', 'Beige', 'Black', 'Blue', 'Brown', 'Burgundy', 'Camel Brown', 'Charcoal', 'Coffee Brown', 'Copper', 'Coral', 'Cream', 'Fluorescent Green', 'Fuchsia', 'Gold', 'Green', 'Grey', 'Grey Melange', 'Khaki', 'Lavender', 'Lime Green', 'Magenta', 'Maroon', 'Mauve', 'Multi', 'Mustard', 'Navy Blue', 'Nude', 'Off White', 'Olive', 'Orange', 'Peach', 'Pink', 'Purple', 'Red', 'Rose', 'Rust', 'Sea Green', 'Silver', 'Tan', 'Taupe', 'Teal', 'Turquoise Blue', 'Violet', 'White', 'Yellow'])

# %%
df1.groupby('colour').first()
# Out:
#                    Unnamed: 0        p_id  \
# colour
# Assorted                  359  16305390.0
# Beige                       7  14951330.0
# Black                       0  17048614.0
# Blue                       20  15055304.0
# Brown                     166  13652412.0
# Burgundy                   30  11459658.0
# Camel Brown               804  11110488.0
# Charcoal                   77  17104862.0
# Coffee Brown              733  12419034.0
# Copper                    860  15790534.0
# Coral                     444  13238592.0
# Cream                     219  17102460.0
# Fluorescent Green          40  18957838.0
# Fuchsia                   374  16874062.0
# Gold                      230  14393508.0
# Green                       9  17048604.0
# Grey                      153  14036824.0
# Grey Melange               65  13391802.0
# Khaki                     776  18408918.0
# Lavender                   47  16857670.0
# Lime Green                 29  18829920.0
# ...

# %%
df1.groupby('avg_rating')['price'].sum()
# Out:
# avg_rating
# 1.000000     19006.0
# 1.500000     16599.0
# 1.666667      6898.0
# 1.727273      2099.0
# 1.750000      5999.0
#               ...
# 4.916667      7196.0
# 4.923077      5997.0
# 4.928571      5590.0
# 4.950000      1699.0
# 5.000000    362931.0
# Name: price, Length: 2368, dtype: float64

# %%
sns.pairplot(df1, kind="scatter",hue='colour')
plt.show()

# %%
df2=  df[['price','brand','colour','avg_rating']]
df2
# Out:
#         price           brand     colour  avg_rating
# 0      5099.0       Khushal K      Black    4.418399
# 1      5899.0         InWeave     Orange    4.119334
# 2      4899.0       Anubhutee  Navy Blue    4.161530
# 3      3699.0            Nayo        Red    4.088986
# 4      1350.0           AHIKA      Black    3.978377
# ...       ...             ...        ...         ...
# 14325  2299.0  Flying Machine       Blue    4.076923
# 14326  2299.0          Juelle      Green         NaN
# 14327  2299.0       Vero Moda       Pink         NaN
# 14328  2299.0       Vero Moda       Blue         NaN
# 14329  2299.0       Vero Moda       Grey         NaN
#
# [14330 rows x 4 columns]

# %%
sns.pairplot(df2, kind="scatter")
plt.show()
